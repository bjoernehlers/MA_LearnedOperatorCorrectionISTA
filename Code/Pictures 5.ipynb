# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fw_loss = np.load('runs/run_20220826_matrix_ISTA/fw_loss.npy')
adj_loss = np.load('runs/run_20220826_matrix_ISTA/adjoint_loss.npy')
Test_dic = np.load('runs/run_20220826_matrix_ISTA/Test/test_dict_iter_49.npy',allow_pickle=True).item()

# %%
plt.plot(adj_loss.T)
plt.yscale('log')

# %%
plt.plot(Test_dic.get('FwL')/(256*96)*.001)

# %%
plt.plot(Test_dic.get('AdL')/(64**2)*0.001)
